# %%
#import libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#load the dataset
housing_data = pd.read_csv(r'C:\Users\Wahaj Sajid\Desktop\Datasets\Housing.csv')
data = pd.read_csv(r'C:\Users\Wahaj Sajid\Desktop\Datasets\Housing.csv')

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
housing_data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
#normalize the data
y_scaler = StandardScaler()
x_scaler = StandardScaler()
#scaling y
housing_data['sealed_price'] = y_scaler.fit_transform(housing_data[['price']])
#scaling x
# housing_data['area'] = x_scaler.fit_transform(housing_data[['area']])
# housing_data['bedrooms'] = x_scaler.fit_transform(housing_data[['bedrooms']])
# housing_data['bathrooms'] = x_scaler.fit_transform(housing_data[['bathrooms']])
# housing_data['stories'] = x_scaler.fit_transform(housing_data[['stories']])
# housing_data['parking'] = x_scaler.fit_transform(housing_data[['parking']])

# %%
housing_data = pd.get_dummies(housing_data,columns=['furnishingstatus'])

# %%
#encode the categroical data
label_encoder = LabelEncoder()
housing_data['mainroad'] = label_encoder.fit_transform(housing_data['mainroad'])
housing_data['guestroom'] = label_encoder.fit_transform(housing_data['guestroom'])
housing_data['hotwaterheating'] = label_encoder.fit_transform(housing_data['hotwaterheating'])
housing_data['airconditioning'] = label_encoder.fit_transform(housing_data['airconditioning'])
housing_data['prefarea'] = label_encoder.fit_transform(housing_data['prefarea'])
housing_data['basement'] = label_encoder.fit_transform(housing_data['basement'])
housing_data['furnishingstatus_furnished'] = label_encoder.fit_transform(housing_data['furnishingstatus_furnished'])
housing_data['furnishingstatus_semi-furnished'] = label_encoder.fit_transform(housing_data['furnishingstatus_semi-furnished'])
housing_data['furnishingstatus_unfurnished'] = label_encoder.fit_transform(housing_data['furnishingstatus_unfurnished'])

# %%
#converting the data type
housing_data['furnishingstatus_furnished'] = housing_data['furnishingstatus_furnished'].astype(int)
housing_data['furnishingstatus_semi-furnished'] = housing_data['furnishingstatus_semi-furnished'].astype(int)
housing_data['furnishingstatus_unfurnished'] = housing_data['furnishingstatus_unfurnished'].astype(int)

# %%
x = housing_data.drop(columns=['price', 'sealed_price'], axis=1)
y = housing_data['sealed_price']

# %%
x = x_scaler.fit_transform(x)

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.8)

# %%
#train the neural network
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64,activation='relu', input_shape =(x_train.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='relu')
])

model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['mae'])
model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_split  = 0.2)
# Out:
# Epoch 1/100
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 993ms/step - loss: 1.3682 - mae: 1.0143 - val_loss: 1.3395 - val_mae: 0.9781
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0551 - mae: 0.8909 - val_loss: 1.2126 - val_mae: 0.9018
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9467 - mae: 0.8454 - val_loss: 1.1373 - val_mae: 0.8502
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.8467 - mae: 0.7903 - val_loss: 1.0764 - val_mae: 0.8177
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.7814 - mae: 0.7516 - val_loss: 1.0437 - val_mae: 0.8023
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.7023 - mae: 0.7298 - val_loss: 1.0251 - val_mae: 0.7969
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5044 - mae: 0.5301 - val_loss: 1.0200 - val_mae: 0.8392
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4927 - mae: 0.5203 - val_loss: 1.0188 - val_mae: 0.8386
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4709 - mae: 0.5143 - val_loss: 1.0173 - val_mae: 0.8379
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5196 - mae: 0.5363 - val_loss: 1.0167 - val_mae: 0.8377
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4665 - mae: 0.5002 - val_loss: 1.0172 - val_mae: 0.8381
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4964 - mae: 0.5231 - val_loss: 1.0172 - val_mae: 0.8383
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5146 - mae: 0.5371 - val_loss: 1.0172 - val_mae: 0.8383
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4890 - mae: 0.5216 - val_loss: 1.0165 - val_mae: 0.8379
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5071 - mae: 0.5222 - val_loss: 1.0166 - val_mae: 0.8379
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4632 - mae: 0.4897 - val_loss: 1.0152 - val_mae: 0.8371
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5334 - mae: 0.5458 - val_loss: 1.0144 - val_mae: 0.8366
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5110 - mae: 0.5286 - val_loss: 1.0145 - val_mae: 0.8367
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5152 - mae: 0.5319 - val_loss: 1.0143 - val_mae: 0.8367
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4731 - mae: 0.5114 - val_loss: 1.0134 - val_mae: 0.8362
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5095 - mae: 0.5159 - val_loss: 1.0126 - val_mae: 0.8358
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4806 - mae: 0.5184 - val_loss: 1.0124 - val_mae: 0.8357
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5285 - mae: 0.5206 - val_loss: 1.0115 - val_mae: 0.8352
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5247 - mae: 0.5296 - val_loss: 1.0107 - val_mae: 0.8347
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4881 - mae: 0.5064 - val_loss: 1.0105 - val_mae: 0.8346
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5205 - mae: 0.5285 - val_loss: 1.0102 - val_mae: 0.8344

# %%
#predict the model

# area = 8960
# bedrooms = 4
# bathrooms = 2
# stories = 3
# parking = 2

# area = x_scaler.transform([[area]])[0][0]
# bedrooms = x_scaler.transform([[bedrooms]])[0][0]
# bathrooms = x_scaler.transform([[bathrooms]])[0][0]
# stories = x_scaler.transform([[stories]])[0][0]
# parking = x_scaler.transform([[parking]])[0][0]


# test_features = np.array([[area, bedrooms, bathrooms, stories, 1, 0, 0, 0, 1, parking, 0, 1, 0 ,0]])
# prediction = model.predict(test_features)
# predict = y_scaler.inverse_transform(prediction)
# print(predict[0][0])

test_features = [[8960, 4, 4, 4, 1, 0, 0, 0, 1, 3, 0, 1, 0 ,0]]
scaled_test_features = x_scaler.transform(test_features)
prediction = model.predict(scaled_test_features)
predict = y_scaler.inverse_transform(prediction)
print(predict[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 12253381.0
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#evaluate the model
loss,mse = model.evaluate(x_test, y_test)
print(f"Loss: ",loss)
print(f"mse: ", mse)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7140 - mae: 0.6854
# Loss:  0.7028948068618774
# mse:  0.6844763159751892

# %%
pre = model.predict(x_test)
print(f"mean squared error:", mean_squared_error(y_test, pre))
print(f"mean absolute error:", mean_absolute_error(y_test, pre))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# mean squared error: 0.7028948216672652
# mean absolute error: 0.6844763103625553
