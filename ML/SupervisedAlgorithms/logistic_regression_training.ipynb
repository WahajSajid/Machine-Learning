# %%
#import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
#load the data
loadData = sns.load_dataset("iris")
data = pd.DataFrame(loadData)
for species_row, sepal_length_row, sepal_width_row, petal_length_row, petal_width_row in zip(data['species'],data['sepal_length'], data['sepal_width'], data['petal_length'], data['petal_width']):
    print(f"Specie:{species_row},Sepal Length: {sepal_length_row}, Sepal Width: {sepal_width_row}, Petal Length: {petal_length_row}, Petal Width: {petal_width_row}")
# Out:
# Specie:setosa,Sepal Length: 5.1, Sepal Width: 3.5, Petal Length: 1.4, Petal Width: 0.2
# Specie:setosa,Sepal Length: 4.9, Sepal Width: 3.0, Petal Length: 1.4, Petal Width: 0.2
# Specie:setosa,Sepal Length: 4.7, Sepal Width: 3.2, Petal Length: 1.3, Petal Width: 0.2
# Specie:setosa,Sepal Length: 4.6, Sepal Width: 3.1, Petal Length: 1.5, Petal Width: 0.2
# Specie:setosa,Sepal Length: 5.0, Sepal Width: 3.6, Petal Length: 1.4, Petal Width: 0.2
# Specie:setosa,Sepal Length: 5.4, Sepal Width: 3.9, Petal Length: 1.7, Petal Width: 0.4
# Specie:setosa,Sepal Length: 4.6, Sepal Width: 3.4, Petal Length: 1.4, Petal Width: 0.3
# Specie:setosa,Sepal Length: 5.0, Sepal Width: 3.4, Petal Length: 1.5, Petal Width: 0.2
# Specie:setosa,Sepal Length: 4.4, Sepal Width: 2.9, Petal Length: 1.4, Petal Width: 0.2
# Specie:setosa,Sepal Length: 4.9, Sepal Width: 3.1, Petal Length: 1.5, Petal Width: 0.1
# Specie:setosa,Sepal Length: 5.4, Sepal Width: 3.7, Petal Length: 1.5, Petal Width: 0.2
# ...

# %%
# encode the categorical data
encoder = LabelEncoder()
data['species'] = encoder.fit_transform(data['species'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
# specifying data x and y
x = data.drop(columns=['species'])
y = data['species']

#train test split the model
x_traint, x_test, y_traint, y_test = train_test_split(x, y, test_size=0.8,)

#train the model
model = LogisticRegression()
model.fit(x_traint, y_traint)
# Out:
# LogisticRegression()

# %%
# predict the model

testData = {"sepal_length": [3.1],
            "sepal_width": [2.5],
            "petal_length": [3.4],
            "petal_width": [1.2]}
testDataFrame = pd.DataFrame(testData)

predict = model.predict(testDataFrame)
print(predict)
# Out:
# [1]

# %%
#test the model
print("Accuracy: ", accuracy_score(y_test, predict))
print("Confusion Matrix:\n", confusion_matrix(y_test, predict))
print("Classification Report: \n", classification_report(y_test, predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 2
#       1 #test the model
# ----> 2 print("Accuracy: ", accuracy_score(y_test, predict))
#       3 print("Confusion Matrix:\n", confusion_matrix(y_test, predict))
#       4 print("Classification Report: \n", classification_report(y_test, predict))
#
# File c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
# ...
