# %%
#import libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#load the dataset
housing_data = pd.read_csv(r'C:\Users\Wahaj Sajid\Desktop\Datasets\Housing.csv')

# %%
housing_data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
#      sealed_price
# 0        4.566365
# 1        4.004484
# 2        4.004484
# 3        3.985755
# 4        3.554979
# ..            ...
# 540     -1.576868
# 541     -1.605149
# 542     -1.614327
# 543     -1.614327
# 544     -1.614327
#
# [545 rows x 14 columns]

# %%
#normalize the data
y_scaler = StandardScaler()
housing_data['sealed_price'] = y_scaler.fit_transform(housing_data[['price']])

# %%
housing_data = pd.get_dummies(housing_data,columns=['furnishingstatus'])

# %%
#encode the categroical data
label_encoder = LabelEncoder()
housing_data['mainroad'] = label_encoder.fit_transform(housing_data['mainroad'])
housing_data['guestroom'] = label_encoder.fit_transform(housing_data['guestroom'])
housing_data['hotwaterheating'] = label_encoder.fit_transform(housing_data['hotwaterheating'])
housing_data['airconditioning'] = label_encoder.fit_transform(housing_data['airconditioning'])
housing_data['prefarea'] = label_encoder.fit_transform(housing_data['prefarea'])
housing_data['basement'] = label_encoder.fit_transform(housing_data['basement'])
housing_data['furnishingstatus_furnished'] = label_encoder.fit_transform(housing_data['furnishingstatus_furnished'])
housing_data['furnishingstatus_semi-furnished'] = label_encoder.fit_transform(housing_data['furnishingstatus_semi-furnished'])
housing_data['furnishingstatus_unfurnished'] = label_encoder.fit_transform(housing_data['furnishingstatus_unfurnished'])

# %%
#converting the data type
housing_data['furnishingstatus_furnished'] = housing_data['furnishingstatus_furnished'].astype(int)
housing_data['furnishingstatus_semi-furnished'] = housing_data['furnishingstatus_semi-furnished'].astype(int)
housing_data['furnishingstatus_unfurnished'] = housing_data['furnishingstatus_unfurnished'].astype(int)

# %%
x = housing_data.drop(columns=['price', 'sealed_price'], axis=1)
y = housing_data['sealed_price']

# %%
#normalize the data
x_scaler = StandardScaler()
x = x_scaler.fit_transform(x)

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.8)

# %%
#train the neural network
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64,activation='relu', input_shape =(x_train.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['mae'])
model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_split  = 0.2)
# Out:
# Epoch 1/100
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - loss: 1.1730 - mae: 0.7252 - val_loss: 0.4537 - val_mae: 0.5080
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.9551 - mae: 0.6409 - val_loss: 0.4199 - val_mae: 0.4994
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.8957 - mae: 0.6028 - val_loss: 0.4052 - val_mae: 0.4953
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.6824 - mae: 0.5436 - val_loss: 0.3974 - val_mae: 0.4863
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6193 - mae: 0.4873 - val_loss: 0.3989 - val_mae: 0.4813
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5718 - mae: 0.4643 - val_loss: 0.4134 - val_mae: 0.4855
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5452 - mae: 0.4502 - val_loss: 0.4365 - val_mae: 0.4898
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5275 - mae: 0.4427 - val_loss: 0.4588 - val_mae: 0.4959
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.6038 - mae: 0.4787 - val_loss: 0.4799 - val_mae: 0.5066
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3358 - mae: 0.3718 - val_loss: 0.4946 - val_mae: 0.5151
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.4204 - mae: 0.3914 - val_loss: 0.5065 - val_mae: 0.5231
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.3836 - mae: 0.3640 - val_loss: 0.5123 - val_mae: 0.5304
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.4110 - mae: 0.3926 - val_loss: 0.5183 - val_mae: 0.5360
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3281 - mae: 0.3510 - val_loss: 0.5260 - val_mae: 0.5405
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.3462 - mae: 0.3541 - val_loss: 0.5389 - val_mae: 0.5457
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3325 - mae: 0.3405 - val_loss: 0.5477 - val_mae: 0.5484
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0274 - mae: 0.1025 - val_loss: 0.7619 - val_mae: 0.6395
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0203 - mae: 0.0869 - val_loss: 0.7633 - val_mae: 0.6408
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0240 - mae: 0.0918 - val_loss: 0.7644 - val_mae: 0.6414
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0182 - mae: 0.0836 - val_loss: 0.7664 - val_mae: 0.6415
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0161 - mae: 0.0734 - val_loss: 0.7683 - val_mae: 0.6415
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0212 - mae: 0.0864 - val_loss: 0.7699 - val_mae: 0.6425
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0224 - mae: 0.0886 - val_loss: 0.7715 - val_mae: 0.6449
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0127 - mae: 0.0680 - val_loss: 0.7741 - val_mae: 0.6454
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0161 - mae: 0.0753 - val_loss: 0.7761 - val_mae: 0.6463
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0196 - mae: 0.0832 - val_loss: 0.7767 - val_mae: 0.6461
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0166 - mae: 0.0763 - val_loss: 0.7768 - val_mae: 0.6451
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0129 - mae: 0.0689 - val_loss: 0.7784 - val_mae: 0.6459
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0134 - mae: 0.0679 - val_loss: 0.7831 - val_mae: 0.6493
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0113 - mae: 0.0648 - val_loss: 0.7837 - val_mae: 0.6494
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0125 - mae: 0.0689 - val_loss: 0.7866 - val_mae: 0.6499
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0168 - mae: 0.0740 - val_loss: 0.7864 - val_mae: 0.6497
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0166 - mae: 0.0739 - val_loss: 0.7852 - val_mae: 0.6493
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0149 - mae: 0.0699 - val_loss: 0.7861 - val_mae: 0.6493
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0100 - mae: 0.0586 - val_loss: 0.7880 - val_mae: 0.6503
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0140 - mae: 0.0695 - val_loss: 0.7902 - val_mae: 0.6510
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0111 - mae: 0.0604 - val_loss: 0.7922 - val_mae: 0.6514
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0141 - mae: 0.0684 - val_loss: 0.7943 - val_mae: 0.6523
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0087 - mae: 0.0551 - val_loss: 0.7952 - val_mae: 0.6522
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0120 - mae: 0.0599 - val_loss: 0.7967 - val_mae: 0.6532
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0100 - mae: 0.0565 - val_loss: 0.7979 - val_mae: 0.6539
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0101 - mae: 0.0595 - val_loss: 0.7979 - val_mae: 0.6541
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0104 - mae: 0.0555 - val_loss: 0.7991 - val_mae: 0.6551
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0114 - mae: 0.0601 - val_loss: 0.7990 - val_mae: 0.6552
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0091 - mae: 0.0547 - val_loss: 0.7994 - val_mae: 0.6549
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0076 - mae: 0.0468 - val_loss: 0.8011 - val_mae: 0.6556
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0109 - mae: 0.0575 - val_loss: 0.8030 - val_mae: 0.6559
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0086 - mae: 0.0519 - val_loss: 0.8052 - val_mae: 0.6569
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0093 - mae: 0.0515 - val_loss: 0.8069 - val_mae: 0.6578
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0075 - mae: 0.0472 - val_loss: 0.8078 - val_mae: 0.6592
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0080 - mae: 0.0495 - val_loss: 0.8077 - val_mae: 0.6595
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0080 - mae: 0.0470 - val_loss: 0.8082 - val_mae: 0.6596
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0091 - mae: 0.0534 - val_loss: 0.8079 - val_mae: 0.6586
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0069 - mae: 0.0449 - val_loss: 0.8084 - val_mae: 0.6583

# %%
#predict the model
test_features = [[8960, 4, 4, 4, 1, 0, 0, 0, 1, 3, 0, 1, 0 ,0]]
scaled_test_features = x_scaler.transform(test_features)
prediction = model.predict(scaled_test_features)
predict = y_scaler.inverse_transform(prediction)
print(predict[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 11627130.0
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#evaluate the model
loss,mse = model.evaluate(x_test,y_test)
print(f"Loss: ",loss)
print(f"mse: ", mse)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6251 - mae: 0.5882
# Loss:  0.635871946811676
# mse:  0.5957486033439636
