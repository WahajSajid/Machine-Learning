# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import BinaryCrossentropy, MeanSquaredError

# %%
#load the data
data = pd.read_csv(r'C:\Users\Wahaj Sajid\Desktop\Datasets\heart_disease_data\framingham.csv')
data_test = pd.read_csv(r'C:\Users\Wahaj Sajid\Desktop\Datasets\heart_disease_data\framingham.csv')

# %%
data_test.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
data
# Out:
#       male       age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1 -1.234951              0   -0.757974       0                0
# 1        0 -0.418257              0   -0.757974       0                0
# 2        1 -0.184916              1    0.925835       0                0
# 3        0  1.331800              1    1.767740       0                0
# 4        0 -0.418257              1    1.178407       0                0
# ...    ...       ...            ...         ...     ...              ...
# 4233     1  0.048425              1   -0.673784       0                0
# 4234     1  0.165095              1    2.862216       0                0
# 4235     0 -0.184916              1    0.925835       0                0
# 4236     0 -0.651598              1    0.504883       0                0
# 4237     0  0.281766              0   -0.757974       0                0
#
#       prevalentHyp  diabetes   totChol     sysBP     diaBP       BMI  \
# 0                0         0 -0.941346 -1.195907 -1.082625  0.286943
# 1                0         0  0.299595 -0.515187 -0.158988  0.719325
# 2                0         0  0.186782 -0.220209 -0.242955 -0.113502
# 3                1         0 -0.264469  0.800871  1.016549  0.682474
# 4                0         0  1.089284 -0.106755  0.092912 -0.663807
# ...            ...       ...       ...       ...       ...       ...
# 4233             1         0  1.721036  2.116930  0.764648  0.041271
# 4234             0         0 -0.670595 -0.265590 -0.242955 -1.496634
# 4235             0         0  0.254470 -0.061374 -0.914691 -0.934046
# 4236             0         0 -0.602907 -0.265590  0.344813 -1.631754
# 4237             0         0  0.728283  0.052079  0.008946 -1.064252
#
#       heartRate   glucose  TenYearCHD
# 0      0.342744 -0.217517           0
# 1      1.590275 -0.261311           0
# 2     -0.073099 -0.524078           0
# 3     -0.904786  0.921141           1
# 4      0.758588  0.132840           0
# ...         ...       ...         ...
# 4233  -0.821617  0.176634           1
# 4234  -0.904786 -0.611667           0
# 4235   0.675419  0.176634           0
# 4236   0.841756  0.000000           0
# 4237   0.342744  1.096319           0
#
# [4238 rows x 15 columns]

# %%
print(data.isnull().sum().sort_values(ascending=False))
# Out:
# male               0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
data = data.drop('education', axis =1)

# %%
#imputing the missing values
imputer = SimpleImputer(strategy='mean')
data['glucose'] = imputer.fit_transform(data[['glucose']])
data['BPMeds'] = imputer.fit_transform(data[['BPMeds']])
data['totChol'] = imputer.fit_transform(data[['totChol']])
data['cigsPerDay'] = imputer.fit_transform(data[['cigsPerDay']])
data['BMI'] = imputer.fit_transform(data[['BMI']])
data['heartRate'] = imputer.fit_transform(data[['heartRate']])

# %%
#scaling the data
x_scaler = StandardScaler()
data['age'] = x_scaler.fit_transform(data[['age']])
data['cigsPerDay'] = x_scaler.fit_transform(data[['cigsPerDay']])
data['totChol'] = x_scaler.fit_transform(data[['totChol']])
data['sysBP'] = x_scaler.fit_transform(data[['sysBP']])
data['diaBP'] = x_scaler.fit_transform(data[['diaBP']])
data['BMI'] = x_scaler.fit_transform(data[['BMI']])
data['heartRate'] = x_scaler.fit_transform(data[['heartRate']])
data['glucose'] = x_scaler.fit_transform(data[['glucose']])

# %%
data['BPMeds'] = data['BPMeds'].astype(int)

# %%
#assigning x and y
x = data.drop('TenYearCHD', axis=1)
y = data['TenYearCHD']

# %%
#train test split the model
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.8)

# %%
#train the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape = (x_train.shape[1],)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

early_stop = EarlyStopping(monitor='val_loss',patience=5, restore_best_weights=True )
model.compile(loss = BinaryCrossentropy(), optimizer='adam', metrics=['mae'])
model.fit(x, y,epochs = 50, batch_size=16, callbacks= [early_stop])
# Out:
# Epoch 1/50
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5667 - mae: 0.4057
# Epoch 2/50
# 147/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4235 - mae: 0.2680
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\keras\src\callbacks\early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
#   current = self.get_monitor_value(logs)
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4183 - mae: 0.2633
# Epoch 3/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3944 - mae: 0.2444
# Epoch 4/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3983 - mae: 0.2451
# Epoch 5/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4011 - mae: 0.2470
# Epoch 6/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3866 - mae: 0.2310
# Epoch 7/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3852 - mae: 0.2314
# Epoch 8/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3670 - mae: 0.2299
# Epoch 9/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3868 - mae: 0.2395
# Epoch 10/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3698 - mae: 0.2270
# Epoch 11/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3802 - mae: 0.2347
# Epoch 12/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3712 - mae: 0.2266
# Epoch 13/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3863 - mae: 0.2344
# Epoch 14/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3683 - mae: 0.2229
# Epoch 15/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3882 - mae: 0.2392
# Epoch 16/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3606 - mae: 0.2207
# Epoch 17/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3640 - mae: 0.2244
# Epoch 18/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3741 - mae: 0.2310
# Epoch 19/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3593 - mae: 0.2181
# Epoch 20/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3758 - mae: 0.2275
# Epoch 21/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3840 - mae: 0.2351
# Epoch 22/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3707 - mae: 0.2286
# Epoch 23/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3712 - mae: 0.2261
# Epoch 24/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3685 - mae: 0.2236
# Epoch 25/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3626 - mae: 0.2214
# Epoch 26/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3796 - mae: 0.2305
# Epoch 27/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3729 - mae: 0.2263
# Epoch 28/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3670 - mae: 0.2239
# Epoch 29/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3448 - mae: 0.2125
# Epoch 30/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3701 - mae: 0.2249
# Epoch 31/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3716 - mae: 0.2274
# Epoch 32/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3723 - mae: 0.2250
# Epoch 33/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3656 - mae: 0.2244
# Epoch 34/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3729 - mae: 0.2240
# Epoch 35/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3872 - mae: 0.2322
# Epoch 36/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3605 - mae: 0.2196
# Epoch 37/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3766 - mae: 0.2292
# Epoch 38/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3761 - mae: 0.2279
# Epoch 39/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3596 - mae: 0.2172
# Epoch 40/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3595 - mae: 0.2221
# Epoch 41/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3733 - mae: 0.2282
# Epoch 42/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3776 - mae: 0.2260
# Epoch 43/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3699 - mae: 0.2215
# Epoch 44/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3587 - mae: 0.2186
# Epoch 45/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3703 - mae: 0.2275
# Epoch 46/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3551 - mae: 0.2157
# Epoch 47/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3609 - mae: 0.2200
# Epoch 48/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3664 - mae: 0.2232
# Epoch 49/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3690 - mae: 0.2251
# Epoch 50/50
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3705 - mae: 0.2240

# %%
loss, mae  = model.evaluate(x_test, y_test)
print(f"Loss: ",loss)
print(f"mae: ",mae)
# Out:
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3424 - mae: 0.2164
# Loss:  0.35441508889198303
# mae:  0.21994167566299438

# %%
#predict the model
age = 20
cigsPerDay = 0.0
totChol = 195
sysBP = 150
diaBP = 70
BMI = 26.97
hearRate = 100
glucose = 77

age = x_scaler.transform([[age]])[0][0]
cigsPerDay = x_scaler.transform([[cigsPerDay]])[0][0]
totChol = x_scaler.transform([[totChol]])[0][0]
sysBP = x_scaler.transform([[sysBP]])[0][0]
diaBP = x_scaler.transform([[diaBP]])[0][0]
BMI = x_scaler.transform([[BMI]])[0][0]
hearRate = x_scaler.transform([[hearRate]])[0][0]
glucose = x_scaler.transform([[glucose]])[0][0]

test_features = np.array([[1,age,1,1,1,1,1,1,totChol,sysBP,diaBP,BMI,hearRate,glucose]])

prediction = model.predict(test_features)
if(prediction>=0.5):
    print("The person is likely to develop heart disease in next 10 years")
else:
    print("The person is not likely to develop heart disease in next 10 years")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# The person is likely to develop heart disease in next 10 years
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
