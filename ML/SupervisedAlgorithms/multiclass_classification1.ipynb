# %% [markdown]
# # Classification of Flowers (using iris dataset) the algorithm used is Multiclass Classification Neural Network (Softmax)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import pandas as pd
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
#load the dataset
iris_data = sns.load_dataset('iris')
data = sns.load_dataset('iris')

# %%
data.tail(70)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 80            5.5          2.4           3.8          1.1  versicolor
# 81            5.5          2.4           3.7          1.0  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# 84            5.4          3.0           4.5          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [70 rows x 5 columns]

# %%
iris_data.tail(70)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 80            5.5          2.4           3.8          1.1  versicolor
# 81            5.5          2.4           3.7          1.0  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# 84            5.4          3.0           4.5          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [70 rows x 5 columns]

# %%
#encode the data
encoder = LabelEncoder()
iris_data['species'] = encoder.fit_transform(iris_data[['species']])
# Out:
# c:\Users\Wahaj Sajid\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#defining x and y
x = iris_data.drop('species', axis=1)
y = iris_data['species']

# %%
#train test split the model 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.8)

# %%
#train the model
model = Sequential([
    Dense(units=30, activation='relu'),
    Dense(units=10, activation='relu'),
    Dense(units=3, activation='softmax')
])
model.compile(loss = SparseCategoricalCrossentropy(),optimizer = 'adam')
model.fit(x_train, y_train, epochs = 50, batch_size = 25)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.8426
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8549
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8280
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.7957
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7943
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.7551
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.7584
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.7550
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.7119
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7362
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7179
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.7245
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7165
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7088
# Epoch 15/50
# ...

# %%
#test the model
test_features = np.array([[6.7,3.0,5.2 ,2.5]])
logits = model(test_features)
prediction = tf.nn.softmax(logits)
print(prediction)
# Out:
# tf.Tensor([[0.26567957 0.4072449  0.32707545]], shape=(1, 3), dtype=float32)

# %%
#test the model
test_features = np.array([[6.7,3.0,5.2 ,2.5]])

predict = model.predict(test_features)

output1, output2,output3 = predict[0]
if(output1 > output2 and output1 > output3):
    print('Setosa')
elif(output2 > output1 and output2 > output3):
    print('Versicolor')
else: 
    print('virginica')

print(predict)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# virginica
# [[0.10093864 0.2028706  0.69619083]]

# %%
#evaluate the model
loss = model.evaluate(x_test, y_test)
print(loss)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6715
# 0.6353549957275391
