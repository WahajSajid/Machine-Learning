# %%
#import libraries 
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Log Transformation

# %%
path = r'C:\Users\Wahaj Sajid\Downloads\WhatsApp Image 2024-12-11 at 9.16.23 PM.jpeg'
img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
c=10
# c = 255 / np.log(1 + np.max(img))
img1 = c * (np.log(1.1+img ))

# norm_image = cv2.normalize(img, None, alpha = 0, beta = 1, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
# img1 = (np.log(1+norm_image ))
img2 = np.array(img1, dtype = np.uint8)

fig, axs = plt.subplots(1,2,figsize=(8,8))
# fig.suptitle('Brightness changes')
axs[0].imshow(img,cmap='gray')
axs[0].axis('off')
axs[0].set_title('Original Image',fontsize='medium')

axs[1].imshow(img2,cmap='gray')
axs[1].axis('off')
axs[1].set_title('Log Transform',fontsize='medium')
plt.show()

img2.min(), img2.max()
# Out:
# (0, 55)
