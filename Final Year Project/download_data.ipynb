# %%
pip install huggingface_hub[hf_xet]
# Out:
# Requirement already satisfied: huggingface_hub[hf_xet] in c:\users\wahaj sajid\anaconda3\lib\site-packages (0.35.0)
# Requirement already satisfied: filelock in c:\users\wahaj sajid\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (6.0.2)
# Requirement already satisfied: requests in c:\users\wahaj sajid\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (4.12.2)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface_hub[hf_xet])
#   Downloading hf_xet-1.1.10-cp37-abi3-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: colorama in c:\users\wahaj sajid\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub[hf_xet]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wahaj sajid\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (2025.8.3)
# Downloading hf_xet-1.1.10-cp37-abi3-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 541.6 kB/s eta 0:00:05
#    ------- -------------------------------- 0.5/2.8 MB 541.6 kB/s eta 0:00:05
#    ------- -------------------------------- 0.5/2.8 MB 541.6 kB/s eta 0:00:05
#    ------- -------------------------------- 0.5/2.8 MB 541.6 kB/s eta 0:00:05
#    ------- -------------------------------- 0.5/2.8 MB 541.6 kB/s eta 0:00:05
#    ----------- ---------------------------- 0.8/2.8 MB 342.4 kB/s eta 0:00:06
#    ----------- ---------------------------- 0.8/2.8 MB 342.4 kB/s eta 0:00:06
#    ----------- ---------------------------- 0.8/2.8 MB 342.4 kB/s eta 0:00:06
#    ----------- ---------------------------- 0.8/2.8 MB 342.4 kB/s eta 0:00:06
#    -------------- ------------------------- 1.0/2.8 MB 324.7 kB/s eta 0:00:06
#    -------------- ------------------------- 1.0/2.8 MB 324.7 kB/s eta 0:00:06
#    -------------- ------------------------- 1.0/2.8 MB 324.7 kB/s eta 0:00:06
#    -------------- ------------------------- 1.0/2.8 MB 324.7 kB/s eta 0:00:06
#    -------------- ------------------------- 1.0/2.8 MB 324.7 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ------------------ --------------------- 1.3/2.8 MB 294.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.6/2.8 MB 211.3 kB/s eta 0:00:06
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    -------------------------- ------------- 1.8/2.8 MB 155.8 kB/s eta 0:00:07
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    ----------------------------- ---------- 2.1/2.8 MB 141.5 kB/s eta 0:00:06
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    --------------------------------- ------ 2.4/2.8 MB 135.8 kB/s eta 0:00:04
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 MB 129.7 kB/s eta 0:00:02
#    ---------------------------------------- 2.8/2.8 MB 121.8 kB/s eta 0:00:00
# Installing collected packages: hf-xet
# Successfully installed hf-xet-1.1.10
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries
from huggingface_hub import login
from huggingface_hub import snapshot_download
import datasets
import pandas as pd
from tqdm import tqdm
import os
import zipfile

# %%
Token = "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"

login(token=Token)

# %%
repo_id = "MahmoodLab/hest"
local_dir = rf"F:\HEST data"
snapshot_download(repo_id=repo_id, repo_type="dataset", local_dir=local_dir, allow_patterns=["HEST_v1_1_0.csv"])
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# HEST_v1_1_0.csv:   0%|          | 0.00/535k [00:00<?, ?B/s]
# 'F:\\HEST data'

# %%
def download_hest(patterns, local_dir):
    repo_id = 'MahmoodLab/hest'
    snapshot_download(repo_id=repo_id, allow_patterns=patterns, repo_type="dataset", local_dir=local_dir)

    seg_dir = os.path.join(local_dir, 'cellvit_seg')
    if os.path.exists(seg_dir):
        print('Unzipping cell vit segmentation...')
        for filename in tqdm([s for s in os.listdir(seg_dir) if s.endswith('.zip')]):
            path_zip = os.path.join(seg_dir, filename)
                        
            with zipfile.ZipFile(path_zip, 'r') as zip_ref:
                zip_ref.extractall(seg_dir)

# %%
local_dir= rf"F:\Breast Data" # hest will be dowloaded to this folder
meta_df = pd.read_csv(rf"F:\HEST data\HEST_v1_1_0.csv")

# Filter the dataframe by organ, oncotree code...
meta_df = meta_df[meta_df['oncotree_code'] == 'IDC']
meta_df = meta_df[meta_df['organ'] == 'Breast']

ids_to_query = meta_df['id'].values

list_patterns = [f"*{id}[_.]**" for id in ids_to_query]
download_hest(list_patterns, local_dir) # see method definition above
# Out:
# Fetching 1488 files:   0%|          | 0/1488 [00:00<?, ?it/s]
# cellvit_seg/NCBI783_cellvit_seg.geojson.(…):   0%|          | 0.00/23.8M [00:00<?, ?B/s]
# cellvit_seg/NCBI784_cellvit_seg.parquet:   0%|          | 0.00/24.4M [00:00<?, ?B/s]
# cellvit_seg/NCBI776_cellvit_seg.parquet:   0%|          | 0.00/21.8M [00:00<?, ?B/s]
# cellvit_seg/SPA0_cellvit_seg.geojson.zip:   0%|          | 0.00/5.15M [00:00<?, ?B/s]
# cellvit_seg/NCBI783_cellvit_seg.parquet:   0%|          | 0.00/26.0M [00:00<?, ?B/s]
# cellvit_seg/NCBI784_cellvit_seg.geojson.(…):   0%|          | 0.00/21.5M [00:00<?, ?B/s]
# cellvit_seg/NCBI785_cellvit_seg.parquet:   0%|          | 0.00/44.0M [00:00<?, ?B/s]
# cellvit_seg/NCBI785_cellvit_seg.geojson.(…):   0%|          | 0.00/38.9M [00:00<?, ?B/s]
# cellvit_seg/SPA0_cellvit_seg.parquet:   0%|          | 0.00/6.39M [00:00<?, ?B/s]
# cellvit_seg/SPA100_cellvit_seg.geojson.z(…):   0%|          | 0.00/37.8M [00:00<?, ?B/s]
